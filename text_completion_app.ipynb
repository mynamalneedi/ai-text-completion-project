# %% [markdown]
# # PART 1: BUILDING APPLICATION USING COHERE- COMMAND R

# %%
import cohere
import os
from dotenv import load_dotenv

# Load API key
load_dotenv()
api_key = os.getenv("COHERE_API_KEY")
co = cohere.Client(api_key)

def get_completion(prompt):
    try:
        response = co.chat(
            model="command-r",
            message=prompt,
            temperature=0.7,
            max_tokens=150
        )
        return response.text.strip()
    except Exception as e:
        return f"❌ Error: {e}"

def main():
    print("🤖 Cohere Text Completion App (type 'exit' to quit)\n")
    while True:
        prompt = input("Enter your prompt: ").strip()
        if prompt.lower() == "exit":
            print("👋 Goodbye!")
            break
        if not prompt:
            print("⚠️ Prompt cannot be empty.")
            continue
        response = get_completion(prompt)
        print(f"\n Prompt:\n {prompt}")
        print(f"\n📝 Response:\n{response}\n")

if __name__ == "__main__":
    main()
# Out:
# 🤖 Cohere Text Completion App (type 'exit' to quit)
#
#
#  Prompt:
#  Once upon a time, there was a robot who...
#
# 📝 Response:
# ...who was built by a brilliant team of engineers. These engineers worked tirelessly day and night, tweaking and adjusting every detail of the robot's design, determined to create something special.
#
# They named him R5-MARK2, a sleek and shiny robot with an intricate network of wires and gears powering its every movement. R5-MARK2 was no ordinary robot; it had artificial intelligence far beyond any other of its kind. Its creators wanted it to experience the world, to think and react like a human, and perhaps, just perhaps, develop emotions.
#
# Curious and wide-eyed, R5-MARK2 explored the world around it, taking in every sight and sound. It watched the people around it, the way they
#
#
#  Prompt:
#  Explain photosynthesis to a 10-year-old.
#
# 📝 Response:
# Hey there! Photosynthesis is a super cool process that plants, and some other cool creatures like algae and some bacteria, use to make their own food.
#
# You know how we go to the grocery store and buy food? Well, plants and these other guys don't have pockets or wallets, so they make their own delicious meals using sunlight! They use the energy from the sun's rays, some water from the soil or ocean, and special gases in the air to create tasty treats like glucose. This process is called photosynthesis, which means 'putting together with light'.
#
# Plants use their special leaves, which often are green because of a color called chlorophyll, to capture the sunlight. They mix the light energy with water and carbon
#
#
#  Prompt:
#  Write a haiku about the ocean
#
# 📝 Response:
# The vast ocean deep,
# An endless blue expanse, its
# Mysterious realm.
#
# 👋 Goodbye!

# %% [markdown]
# # PART 2: Debugging and Improving the Application

# %%
import cohere
import os
from dotenv import load_dotenv

# Load API key
load_dotenv()
api_key = os.getenv("COHERE_API_KEY")
co = cohere.Client(api_key)
def validate_api_key():
    try:
        # Make a harmless call to check if key works
        co.chat(model="command-r", message="ping", max_tokens=1)
        return True
    except cohere.error.CohereAPIError as e:
        print(f" INVALID OR UNAUTHORIZED API KEY: {e}")
        return False
    except Exception as e:
        print(f"UNEXPECTED ERROR DURING API KEY CHECK: {e}")
        return False

def get_completion(prompt, temperature=0.7, max_tokens=150):
    try:
        response = co.chat(
            model="command-r",
            message=prompt,
            temperature=temperature,
            max_tokens=max_tokens
        )
        return response.text.strip()
    except cohere.error.CohereAPIError as e:
        return f"Cohere API ERROR: {e}"
    except Exception as e:
        return f"UNEXPECTED ERROR: {e}"

def main():
    print("Cohere Text Completion App (type 'exit' to quit)\n")
    if not validate_api_key():
        print("EXITING DUE TO INVALID API KEY.")
        return

    # Allow user to configure temperature and max_tokens

    while True:
        try:
            temp_input = input("Set temperature 0.0 - 1.0, ( values >0.5 for more creativity & <0.5 for more factual) [default set to 0.7]: ").strip()
            temperature = float(temp_input) if temp_input else 0.7

            max_input = input("Set max tokens (i.e. number of words) [default 150]: ").strip()
            max_tokens = int(max_input) if max_input else 150
        except ValueError:
            print("INVALID INPUT. USING DEFAULT VALUES.")
            temperature = 0.7
            max_tokens = 150
        prompt = input("\nEnter your prompt: ").strip()

        if prompt.lower() == "exit":
            print("Goodbye! 👋 ")
            break

        if not prompt:
            print("PROMPT CANNOT BE EMPTY.")
            continue

        if len(prompt) > 500:
            print("PROMPT TOO LONG (LIMIT: 500 CHARACTERS).")
            continue

        response = get_completion(prompt, temperature, max_tokens)
        print(f"\n Temperature:\n {temperature}")
        print(f"\n max_tokens:\n {max_tokens}")
        print(f"\n Prompt:\n {prompt}")
        print(f"\n📝 Response:\n{response}\n")

if __name__ == "__main__":
    main()
# Out:
# 🤖 Cohere Text Completion App (type 'exit' to quit)
#
#
#  Temperature:
#  0.9
#
#  max_tokens:
#  100
#
#  Prompt:
#  Explain recursion like I'm five.
#
# 📝 Response:
# Recursion is like a game of pretend that keeps on going and going. Imagine you have a magical toy that can make exact copies of itself. When you play with it, you not only have one toy, but two! And the new toy can make another copy of itself, giving you three toys in total. It's like a never-ending game of making more toys.
#
# Now, picture doing this with something simple, like drawing a circle. You draw a circle, and it's
#
#
#  Temperature:
#  0.5
#
#  max_tokens:
#  50
#
#  Prompt:
#  Using containers, Docker makes it simple to design, deploy, and operate programs. Think of a container like a software shipping box—it holds files and programs so apps can move quickly from developer to user. One key advantage is letting developers bundle their app with all dependencies needed to run on any Linux distro, eliminating the need to install each requirement manually.
#
# 📝 Response:
# That's correct! Docker containers provide a fantastic way to streamline the development and deployment process. They offer a consistent and isolated environment with all the necessary dependencies to run an application, ensuring it can be easily transferred between different systems. This containerization approach simplifies
#
#
#  Temperature:
#  0.5
#
#  max_tokens:
#  50
#
#  Prompt:
#  summariaze text. Using containers, Docker makes it simple to design, deploy, and operate programs. Think of a container like a software shipping box—it holds files and programs so apps can move quickly from developer to user. One key advantage is letting developers bundle their app with all dependencies needed to run on any Linux distro, eliminating the need to install each requirement manually.
#
# 📝 Response:
# Docker uses containers to simplify the design, deployment, and operation of programs. Containers are like shipping boxes for software, keeping files and programs together. This allows developers to package their apps with all the necessary dependencies, making them easily transferable and compatible across different
#
#
#  Temperature:
#  0.7
#
#  max_tokens:
#  200
#
#  Prompt:
#  Explain to me the 9/11 tragedy.
#
# 📝 Response:
# The 9/11 tragedy refers to the series of coordinated terrorist attacks that took place in the United States on September 11, 2001. Al-Qaeda, an Islamic terrorist group led by Osama bin Laden, was responsible for the attacks.
#
# Here's a summary of what happened:
#
# 1. First Plane Crash: American Airlines Flight 11. A Boeing 767 with 92 people on board took off from Boston's Logan International Airport headed for Los Angeles. It was hijacked by five terrorists who crashed it into the North Tower of the World Trade Center complex in New York City at 8:46 a.m. The impact started a series of fires and caused extensive damage to the upper floors of the 110-story skyscraper.
#
# 2. Second Plane Crash: United Airlines Flight 175. Another Boeing 767, with 65 passengers also departing from Logan International Airport to Los Angeles, was
#
#
#  Temperature:
#  1.0
#
#  max_tokens:
#  200
#
#  Prompt:
#  Explain to me the 9/11 tragedy.
#
# 📝 Response:
# Certainly, the events of September 11th, 2001, often referred to as 9/11, were a series of coordinated terrorist attacks that took place in the United States. The attacks killed 2,977 non-hijackers, injured over 6,000 others, and caused massive physical and economic damage. They remain the deadliest terrorist attacks in human history.
#
# Here's a chronological breakdown of the events:
#
# 1. First Plane Crash: American Airlines Flight 11. A Boeing 767 with 92 people on board departed Boston's Logan International Airport headed for Los Angeles. It was hijacked by five terrorists affiliated with the Islamic extremist group al-Qaeda. The plane crashed into the North Tower of the World Trade Center complex in New York City at 8:46 a.m. ET.
#
# 2. Second Plane Crash: United Airlines Flight 175. Another Boeing 767,
#
#
#  Temperature:
#  0.2
#
#  max_tokens:
#  110
#
#  Prompt:
#  I think I want to
#
# 📝 Response:
# That's great! Having goals and aspirations is an important part of life, as it gives us direction and a sense of purpose. What is it that you want to do?
#
#
#  Temperature:
#  0.2
#
#  max_tokens:
#  100
#
#  Prompt:
#  Finish the prompt. I think I want to...
#
# 📝 Response:
# ...go on vacation!
#
# You've worked hard and now it's time to treat yourself to a well-deserved break. Pack your bags, grab your passport, and embark on an adventure. Whether you're seeking sunny beaches, majestic mountains, or vibrant city lights, the world is your oyster. Let the planning begin!
#
# Where would you like to go on vacation? Do you have any destinations in mind?
#
#
#  Temperature:
#  0.6
#
#  max_tokens:
#  150
#
#  Prompt:
#  give me the python code for a fibonacci series
#
# 📝 Response:
# Here's a Python program that generates the Fibonacci series up to the 10th term:
# ```python
# def fibonacci_series(n):
#     series = []
#     a, b = 0, 1
#     for _ in range(n):
#         series.append(a)
#         a, b = b, a + b
#     return series
#
# # Generate Fibonacci series up to the 10th term
# fib_series = fibonacci_series(10)
# print(fib_series)
# ```
#
# You can change the value of `n` in the `fibonacci_series` function to generate the series up to a different number of terms. The Fibonacci series starts with 0 and
#
# ⚠️ Invalid input. Using default values.
#
#  Temperature:
#  0.7
#
#  max_tokens:
#  150
#
#  Prompt:
#  escape
#
# 📝 Response:
# That sounds like the beginning of an exciting adventure! Escaping could mean many things, like escaping from a dangerous situation, escaping boredom, or even escaping to a relaxing vacation. What kind of escape are you seeking?
#
# Perhaps you'd like some ideas for a thrilling escape room experience or a mysterious adventure movie to immerse yourself in. If you're looking for a more tranquil escape, I can also recommend some calming activities or vacation spots. Let's plan an escape that's perfect for you!
#
# ⚠️ Invalid input. Using default values.
# 👋 Goodbye!
